# %%
# !pip install nixtla
# Out:
# Requirement already satisfied: nixtla in d:\jn\lib\site-packages (0.5.1)
# Requirement already satisfied: httpx in d:\jn\lib\site-packages (from nixtla) (0.27.0)
# Requirement already satisfied: pandas in d:\jn\lib\site-packages (from nixtla) (2.1.4)
# Requirement already satisfied: pydantic in d:\jn\lib\site-packages (from nixtla) (1.10.12)
# Requirement already satisfied: requests in d:\jn\lib\site-packages (from nixtla) (2.31.0)
# Requirement already satisfied: tenacity in d:\jn\lib\site-packages (from nixtla) (8.2.2)
# Requirement already satisfied: utilsforecast>=0.1.7 in d:\jn\lib\site-packages (from nixtla) (0.1.10)
# Requirement already satisfied: numpy in d:\jn\lib\site-packages (from utilsforecast>=0.1.7->nixtla) (1.26.4)
# Requirement already satisfied: packaging in d:\jn\lib\site-packages (from utilsforecast>=0.1.7->nixtla) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\jn\lib\site-packages (from pandas->nixtla) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\jn\lib\site-packages (from pandas->nixtla) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\jn\lib\site-packages (from pandas->nixtla) (2023.3)
# Requirement already satisfied: anyio in d:\jn\lib\site-packages (from httpx->nixtla) (4.2.0)
# Requirement already satisfied: certifi in d:\jn\lib\site-packages (from httpx->nixtla) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in d:\jn\lib\site-packages (from httpx->nixtla) (1.0.5)
# Requirement already satisfied: idna in d:\jn\lib\site-packages (from httpx->nixtla) (3.4)
# Requirement already satisfied: sniffio in d:\jn\lib\site-packages (from httpx->nixtla) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\jn\lib\site-packages (from httpcore==1.*->httpx->nixtla) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\jn\lib\site-packages (from pydantic->nixtla) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jn\lib\site-packages (from requests->nixtla) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jn\lib\site-packages (from requests->nixtla) (2.0.7)
# Requirement already satisfied: six>=1.5 in d:\jn\lib\site-packages (from python-dateutil>=2.8.2->pandas->nixtla) (1.16.0)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in d:\jn\lib\site-packages (0.2.40)
# Requirement already satisfied: pandas>=1.3.0 in d:\jn\lib\site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in d:\jn\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in d:\jn\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in d:\jn\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in d:\jn\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\jn\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in d:\jn\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in d:\jn\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in d:\jn\lib\site-packages (from yfinance) (3.17.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\jn\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in d:\jn\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in d:\jn\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in d:\jn\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in d:\jn\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\jn\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in d:\jn\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jn\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\jn\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jn\lib\site-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\jn\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)

# %%
# !pip install datasetsforecast
# Out:
# Requirement already satisfied: datasetsforecast in d:\jn\lib\site-packages (0.0.8)
# Requirement already satisfied: aiohttp in d:\jn\lib\site-packages (from datasetsforecast) (3.9.3)
# Requirement already satisfied: fugue>=0.8.1 in d:\jn\lib\site-packages (from datasetsforecast) (0.9.0)
# Requirement already satisfied: numba in d:\jn\lib\site-packages (from datasetsforecast) (0.59.0)
# Requirement already satisfied: numpy in d:\jn\lib\site-packages (from datasetsforecast) (1.26.4)
# Requirement already satisfied: pandas in d:\jn\lib\site-packages (from datasetsforecast) (2.1.4)
# Requirement already satisfied: requests in d:\jn\lib\site-packages (from datasetsforecast) (2.31.0)
# Requirement already satisfied: tqdm in d:\jn\lib\site-packages (from datasetsforecast) (4.65.0)
# Requirement already satisfied: xlrd>=1.0.0 in d:\jn\lib\site-packages (from datasetsforecast) (2.0.1)
# Requirement already satisfied: triad>=0.9.6 in d:\jn\lib\site-packages (from fugue>=0.8.1->datasetsforecast) (0.9.7)
# Requirement already satisfied: adagio>=0.2.4 in d:\jn\lib\site-packages (from fugue>=0.8.1->datasetsforecast) (0.2.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\jn\lib\site-packages (from aiohttp->datasetsforecast) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\jn\lib\site-packages (from aiohttp->datasetsforecast) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\jn\lib\site-packages (from aiohttp->datasetsforecast) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\jn\lib\site-packages (from aiohttp->datasetsforecast) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\jn\lib\site-packages (from aiohttp->datasetsforecast) (1.9.3)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in d:\jn\lib\site-packages (from numba->datasetsforecast) (0.42.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\jn\lib\site-packages (from pandas->datasetsforecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\jn\lib\site-packages (from pandas->datasetsforecast) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\jn\lib\site-packages (from pandas->datasetsforecast) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jn\lib\site-packages (from requests->datasetsforecast) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\jn\lib\site-packages (from requests->datasetsforecast) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jn\lib\site-packages (from requests->datasetsforecast) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\jn\lib\site-packages (from requests->datasetsforecast) (2024.2.2)
# Requirement already satisfied: colorama in d:\jn\lib\site-packages (from tqdm->datasetsforecast) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\jn\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasetsforecast) (1.16.0)
# Requirement already satisfied: pyarrow>=6.0.1 in d:\jn\lib\site-packages (from triad>=0.9.6->fugue>=0.8.1->datasetsforecast) (14.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in d:\jn\lib\site-packages (from triad>=0.9.6->fugue>=0.8.1->datasetsforecast) (2023.10.0)
# Requirement already satisfied: fs in d:\jn\lib\site-packages (from triad>=0.9.6->fugue>=0.8.1->datasetsforecast) (2.4.16)
# Requirement already satisfied: appdirs~=1.4.3 in d:\jn\lib\site-packages (from fs->triad>=0.9.6->fugue>=0.8.1->datasetsforecast) (1.4.4)
# Requirement already satisfied: setuptools in d:\jn\lib\site-packages (from fs->triad>=0.9.6->fugue>=0.8.1->datasetsforecast) (68.2.2)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
from nixtla import NixtlaClient

# %%
nixtla_client = NixtlaClient(api_key='nixtla-tok-2WhMO3zBSmvCWqvVBaBAH31mEBTR6YdwLdEurcwldlkVsex1JoxxKPAYYGXjvkPQxp1Ud77q5qvfCw7y')

carparts = "PRTS"
start = "2018-01-01"
end = "2023-12-15"

data = yf.download(carparts, start=start, end=end)
data.reset_index(inplace=True)
data['Date'] = pd.to_datetime(data['Date'])

data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
train_data = data[(data['Date'] >= '2018-01-01') & (data['Date'] <= '2022-12-31')]
test_data = data[(data['Date'] >= '2023-01-01') & (data['Date'] <= '2023-12-15')]

# %%
nixtla_client.plot(train_data, time_col='Date', target_col='Close')

# %%
data_forecast = nixtla_client.forecast(
    df = train_data,
    h = len(test_data),
    freq='B',
    level=[90],
    finetune_steps=10,
    model='timegpt-1-long-horizon',
    time_col='Date',
    target_col='Close'
)
data_forecast
# Out:
# INFO:nixtla.nixtla_client:Validating inputs...
# INFO:nixtla.nixtla_client:Preprocessing dataframes...
# WARNING:nixtla.nixtla_client:The specified horizon "h" exceeds the model horizon. This may lead to less accurate forecasts. Please consider using a smaller horizon.
# INFO:nixtla.nixtla_client:Calling Forecast Endpoint...
#            Date   TimeGPT  TimeGPT-lo-90  TimeGPT-hi-90
# 0    2023-01-02  5.654178       4.676629       6.631727
# 1    2023-01-03  5.683441       4.979461       6.387420
# 2    2023-01-04  5.702896       4.519034       6.886759
# 3    2023-01-05  5.724617       4.207248       7.241986
# 4    2023-01-06  5.750985       3.879442       7.622528
# ..          ...       ...            ...            ...
# 235  2023-11-27  8.336121       2.579337      14.092905
# 236  2023-11-28  8.405002       2.605657      14.204346
# 237  2023-11-29  8.367685       2.134319      14.601052
# 238  2023-11-30  8.331148       1.556106      15.106190
# 239  2023-12-01  8.315365       1.834535      14.796195
#
# [240 rows x 4 columns]

# %%
nixtla_client.plot(train_data, data_forecast, models=['TimeGPT'], level=[90], time_col='Date', target_col='Close')

# %%
anomalies = nixtla_client.detect_anomalies(train_data, time_col='Date', target_col='Close', freq='B')
nixtla_client.plot(train_data, anomalies, time_col='Date', target_col='Close', plot_anomalies=True)
# Out:
# INFO:nixtla.nixtla_client:Validating inputs...
# INFO:nixtla.nixtla_client:Preprocessing dataframes...
# INFO:nixtla.nixtla_client:Calling Anomaly Detector Endpoint...
# INFO:nixtla.nixtla_client:Using the following exogenous variables: Open, High, Low, Adj Close, Volume

# %%
import matplotlib.pyplot as plt

# Визуализация на историческите данни и прогнозата
plt.figure(figsize=(14, 7))
plt.plot(train_data['Date'], train_data['Close'], label='Historical Data (Train)', color='blue')
plt.plot(test_data['Date'], test_data['Close'], label='Historical Data (Test)', color='green')
plt.plot(test_data['Date'], data_forecast['TimeGPT'], label='TimeGPT', color='red', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Debugging: print the first few rows of data_forecast
print("Forecast data:")
print(data_forecast.head())

# Calculate metrics
rmse = mean_squared_error(test_data['Close'], data_forecast['TimeGPT'], squared=False)
mae = mean_absolute_error(test_data['Close'], data_forecast['TimeGPT'])

# Check for NaN values in data_forecast
if data_forecast['TimeGPT'].isnull().any():
    print("NaN values found in the forecast data")

# Replace zero values in test_data['Close'] with NaN
test_data_non_zero = test_data.copy()
test_data_non_zero['Close'].replace(0, np.nan, inplace=True)

# Drop rows with NaN values resulting from replacement
test_data_non_zero.dropna(subset=['Close'], inplace=True)

# Ensure that the Date column is the same format
data_forecast['Date'] = pd.to_datetime(data_forecast['Date'])
test_data_non_zero['Date'] = pd.to_datetime(test_data_non_zero['Date'])

# Print the first few rows of test_data_non_zero
print("Test data non-zero:")
print(test_data_non_zero.head())

# Align forecasts with the modified test data
aligned_forecast = data_forecast[data_forecast['Date'].isin(test_data_non_zero['Date'])].copy()

# Debugging: print the first few rows of aligned_forecast
print("Aligned forecast data before setting index:")
print(aligned_forecast.head())

# Ensure the indices match
test_data_non_zero.set_index('Date', inplace=True)
aligned_forecast.set_index('Date', inplace=True)

# Debugging: print the first few rows of aligned_forecast after setting index
print("Aligned forecast data after setting index:")
print(aligned_forecast.head())

# Check again for NaN values in the aligned forecast
if aligned_forecast['TimeGPT'].isnull().any():
    print("NaN values found in the aligned forecast data")

# Remove NaN values from aligned_forecast
aligned_forecast.dropna(subset=['TimeGPT'], inplace=True)

# Recalculate MAPE only for the dates that are present in both test_data_non_zero and aligned_forecast
common_dates = test_data_non_zero.index.intersection(aligned_forecast.index)
test_data_non_zero_common = test_data_non_zero.loc[common_dates]
aligned_forecast_common = aligned_forecast.loc[common_dates]

# Debugging: print the first few rows of the common data
print("Common test data:")
print(test_data_non_zero_common.head())
print("Common forecast data:")
print(aligned_forecast_common.head())

# Calculate MAPE
mape = np.mean(np.abs((test_data_non_zero_common['Close'].values - aligned_forecast_common['TimeGPT'].values) / test_data_non_zero_common['Close'].values)) * 100

print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}')
# Out:
# Forecast data:
#          Date   TimeGPT  TimeGPT-lo-90  TimeGPT-hi-90
# 0  2023-01-02  5.654178       4.676629       6.631727
# 1  2023-01-03  5.683441       4.979461       6.387420
# 2  2023-01-04  5.702896       4.519034       6.886759
# 3  2023-01-05  5.724617       4.207248       7.241986
# 4  2023-01-06  5.750985       3.879442       7.622528
# Test data non-zero:
#            Date  Open  High   Low  Close  Adj Close  Volume
# 1259 2023-01-03  6.37  6.51  6.24   6.26       6.26  648000
# 1260 2023-01-04  6.33  6.40  6.21   6.30       6.30  614800
# 1261 2023-01-05  6.29  6.50  6.17   6.40       6.40  523300
# 1262 2023-01-06  6.43  6.55  6.33   6.51       6.51  582900
# 1263 2023-01-09  6.61  6.84  6.55   6.73       6.73  694200
# Aligned forecast data before setting index:
#         Date   TimeGPT  TimeGPT-lo-90  TimeGPT-hi-90
# 1 2023-01-03  5.683441       4.979461       6.387420
# 2 2023-01-04  5.702896       4.519034       6.886759
# 3 2023-01-05  5.724617       4.207248       7.241986
# 4 2023-01-06  5.750985       3.879442       7.622528
# 5 2023-01-09  5.760756       4.183016       7.338496
# Aligned forecast data after setting index:
#              TimeGPT  TimeGPT-lo-90  TimeGPT-hi-90
# Date
# 2023-01-03  5.683441       4.979461       6.387420
# 2023-01-04  5.702896       4.519034       6.886759
# 2023-01-05  5.724617       4.207248       7.241986
# 2023-01-06  5.750985       3.879442       7.622528
# 2023-01-09  5.760756       4.183016       7.338496
# Common test data:
#             Open  High   Low  Close  Adj Close  Volume
# Date
# 2023-01-03  6.37  6.51  6.24   6.26       6.26  648000
# 2023-01-04  6.33  6.40  6.21   6.30       6.30  614800
# 2023-01-05  6.29  6.50  6.17   6.40       6.40  523300
# 2023-01-06  6.43  6.55  6.33   6.51       6.51  582900
# 2023-01-09  6.61  6.84  6.55   6.73       6.73  694200
# Common forecast data:
#              TimeGPT  TimeGPT-lo-90  TimeGPT-hi-90
# Date
# 2023-01-03  5.683441       4.979461       6.387420
# 2023-01-04  5.702896       4.519034       6.886759
# 2023-01-05  5.724617       4.207248       7.241986
# 2023-01-06  5.750985       3.879442       7.622528
# 2023-01-09  5.760756       4.183016       7.338496
# RMSE: 2.8515268242154557
# MAE: 2.4336790204048158
# MAPE: 59.64015418434998

# %%
highest_forecast_price = data_forecast['TimeGPT'].max()
lowest_forecast_price = data_forecast['TimeGPT'].min()

highest_forecast_date = data.loc[data_forecast['TimeGPT'].idxmax()]['Date']
lowest_forecast_date = data.loc[data_forecast['TimeGPT'].idxmin()]['Date']

print(f"Highest forecasted price: {highest_forecast_price} on {highest_forecast_date}")
print(f"Lowest forecasted price: {lowest_forecast_price} on {lowest_forecast_date}")
# Out:
# Highest forecasted price: 8.405001640319824 on 2018-12-10 00:00:00
# Lowest forecasted price: 5.654177665710449 on 2018-01-02 00:00:00
